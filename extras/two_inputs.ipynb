# %%
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

from keras.layers import Dense, Input, Dropout, Flatten, Concatenate
from keras.models import Model
from keras.optimizers import Adam
from tensorflow import float16

import wandb
from wandb.keras import WandbMetricsLogger, WandbModelCheckpoint
import pickle
from transformers import  TFBertModel
bmodel = TFBertModel.from_pretrained('emilyalsentzer/Bio_ClinicalBERT')
# Out:
# 2023-11-09 17:14:22.504527: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-11-09 17:14:24.277916: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14211 MB memory:  -> device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0000:af:00.0, compute capability: 7.0
# Some layers from the model checkpoint at emilyalsentzer/Bio_ClinicalBERT were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at emilyalsentzer/Bio_ClinicalBERT.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
with open('data/dataset.pkl', 'rb') as f:
    dataset = pickle.load(f)

for k, v in dataset.items():
    print(k, v.keys())
# Out:
# sentence dict_keys(['text', 'max_length', 'encoded', 'test', 'train'])
# predication dict_keys(['text', 'max_length', 'encoded', 'test', 'train'])
# concatenated dict_keys(['text', 'max_length', 'encoded', 'test', 'train'])
# label dict_keys(['text', 'test', 'train'])

# %%
def train_model():
    # these are config values that came from wandb sweep passes
    config_defaults= {
        "model_name": "two_input_model",
        "dropout": 0.43,
        "learning_rate": 0.000030,
        "epsilon": 1e-08,
        "loss": "binary_crossentropy",
        "metric": ["accuracy"],
        "epoch": 6,
        "batch_size":4,
        "validation_split": 0.2,
    }
    
    wandb.init(
        project="uminn",
        config=config_defaults
    )

    train_x = (dataset['predication']['train'], dataset['sentence']['train'])
    train_y = dataset['label']['train']
    
    # define the model

    input_preds = Input(shape=(32,), dtype='int32')
    input_sents = Input(shape=(250,), dtype='int32')
    preds_bert_output = bmodel(input_preds)
    sents_bert_output = bmodel(input_sents)
    preds_bert_output = preds_bert_output[1]
    sents_bert_output = sents_bert_output[1]
    hidden_sents_1 = Dense(32, activation='relu')(sents_bert_output)
    dropout_sents_1 = Dropout(wandb.config.dropout)(hidden_sents_1)
    concat = Concatenate()([preds_bert_output, hidden_sents_1])
    dense = Dense(1, activation='sigmoid')(concat)
    two_input_model = Model(inputs=[input_preds, input_sents], outputs=dense)

                         
    opt = Adam(learning_rate = wandb.config.learning_rate, 
               epsilon=wandb.config.epsilon)

    two_input_model.compile(loss=wandb.config.loss, 
                         optimizer=opt, 
                         metrics=['accuracy'])
    
    two_input_model.fit(train_x,
                     train_y,
                     epochs=wandb.config.epoch,
                     validation_split=wandb.config.validation_split,
                     callbacks=[WandbMetricsLogger()])
    
    return two_input_model

# %%
# # just do one to make sure we're OK here
two_input_model = train_model()
wandb.finish()

# %%
# Or do a hyperparameter sweep to find some good settings

sweep_config = {
    'method': 'bayes',
    'name': 'umn-two-input',
    'metric': {
        'name': 'epoch/val_loss',
        'goal': 'minimize'
    },
    'parameters': {
        "dropout": {'min': 0.20, 'max': 0.70},
        "learning_rate": {'values': [5e-5, 3e-5, 2e-5]},
        "epoch": {'min': 6, 'max': 10},
        "batch_size": {'values': [2]}
    },
}

sweep_id = wandb.sweep(sweep_config, project="uminn")
wandb.agent(sweep_id, train_model, count=10)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Create sweep with ID: r4abtlfi
# Sweep URL: https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi
# wandb: Agent Starting Run: oaqs1n4f with config:
# wandb: 	batch_size: 2
# wandb: 	dropout: 0.5566476411397208
# wandb: 	epoch: 10
# wandb: 	learning_rate: 5e-05
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: kgweber (dlhs_rau). Use `wandb login --relogin` to force relogin
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>/home/kgweber/projects/predications/wandb/run-20231109_171434-oaqs1n4f</code>
# Syncing run <strong><a href='https://wandb.ai/dlhs_rau/uminn/runs/oaqs1n4f' target="_blank">sage-sweep-1</a></strong> to <a href='https://wandb.ai/dlhs_rau/uminn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi' target="_blank">https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi</a>
#  View project at <a href='https://wandb.ai/dlhs_rau/uminn' target="_blank">https://wandb.ai/dlhs_rau/uminn</a>
#  View sweep at <a href='https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi' target="_blank">https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi</a>
#  View run at <a href='https://wandb.ai/dlhs_rau/uminn/runs/oaqs1n4f' target="_blank">https://wandb.ai/dlhs_rau/uminn/runs/oaqs1n4f</a>
# Epoch 1/10
# 60/60 [==============================] - 56s 703ms/step - loss: 0.6894 - accuracy: 0.5516 - val_loss: 0.6573 - val_accuracy: 0.5813
# Epoch 2/10
# 60/60 [==============================] - 39s 654ms/step - loss: 0.6567 - accuracy: 0.6021 - val_loss: 0.6590 - val_accuracy: 0.6000
# Epoch 3/10
# 60/60 [==============================] - 39s 653ms/step - loss: 0.6090 - accuracy: 0.6693 - val_loss: 0.6258 - val_accuracy: 0.6354
# Epoch 4/10
# 60/60 [==============================] - 39s 653ms/step - loss: 0.4958 - accuracy: 0.7714 - val_loss: 0.6796 - val_accuracy: 0.6250
# Epoch 5/10
# 60/60 [==============================] - 39s 653ms/step - loss: 0.3849 - accuracy: 0.8313 - val_loss: 0.7916 - val_accuracy: 0.6021
# Epoch 6/10
# 60/60 [==============================] - 39s 653ms/step - loss: 0.2384 - accuracy: 0.9031 - val_loss: 1.0949 - val_accuracy: 0.6250
# Epoch 7/10
# 60/60 [==============================] - 39s 653ms/step - loss: 0.1642 - accuracy: 0.9417 - val_loss: 1.0323 - val_accuracy: 0.6313
# Epoch 8/10
# 60/60 [==============================] - 39s 653ms/step - loss: 0.1060 - accuracy: 0.9589 - val_loss: 1.3247 - val_accuracy: 0.6125
# Epoch 9/10
# 60/60 [==============================] - 39s 653ms/step - loss: 0.0472 - accuracy: 0.9828 - val_loss: 1.7504 - val_accuracy: 0.6313
# Epoch 10/10
# 60/60 [==============================] - 39s 653ms/step - loss: 0.0746 - accuracy: 0.9745 - val_loss: 1.9944 - val_accuracy: 0.5979
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>▁▂▃▅▆▇▇███</td></tr><tr><td>epoch/epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>epoch/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch/loss</td><td>██▇▆▅▃▂▂▁▁</td></tr><tr><td>epoch/val_accuracy</td><td>▁▃█▇▄▇▇▅▇▃</td></tr><tr><td>epoch/val_loss</td><td>▁▁▁▁▂▃▃▅▇█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch/accuracy</td><td>0.97448</td></tr><tr><td>epoch/epoch</td><td>9</td></tr><tr><td>epoch/learning_rate</td><td>5e-05</td></tr><tr><td>epoch/loss</td><td>0.07456</td></tr><tr><td>epoch/val_accuracy</td><td>0.59792</td></tr><tr><td>epoch/val_loss</td><td>1.99439</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sage-sweep-1</strong> at: <a href='https://wandb.ai/dlhs_rau/uminn/runs/oaqs1n4f' target="_blank">https://wandb.ai/dlhs_rau/uminn/runs/oaqs1n4f</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231109_171434-oaqs1n4f/logs</code>
# wandb: Agent Starting Run: yci0efr4 with config:
# wandb: 	batch_size: 2
# wandb: 	dropout: 0.5254547559667291
# wandb: 	epoch: 7
# wandb: 	learning_rate: 2e-05
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb version 0.16.0 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>/home/kgweber/projects/predications/wandb/run-20231109_172149-yci0efr4</code>
# Syncing run <strong><a href='https://wandb.ai/dlhs_rau/uminn/runs/yci0efr4' target="_blank">peach-sweep-2</a></strong> to <a href='https://wandb.ai/dlhs_rau/uminn' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi' target="_blank">https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi</a>
#  View project at <a href='https://wandb.ai/dlhs_rau/uminn' target="_blank">https://wandb.ai/dlhs_rau/uminn</a>
#  View sweep at <a href='https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi' target="_blank">https://wandb.ai/dlhs_rau/uminn/sweeps/r4abtlfi</a>
#  View run at <a href='https://wandb.ai/dlhs_rau/uminn/runs/yci0efr4' target="_blank">https://wandb.ai/dlhs_rau/uminn/runs/yci0efr4</a>
# Epoch 1/7
#  9/60 [===>..........................] - ETA: 30s - loss: 0.2912 - accuracy: 0.8993
# 2023-11-09 17:22:31.202138: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 23.44MiB (rounded to 24576000)requested by op model/tf_bert_model/bert/encoder/layer_._11/output/LayerNorm/batchnorm_1/mul_2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-11-09 17:22:31.202282: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2023-11-09 17:22:31.202313: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 120, Chunks in use: 119. 30.0KiB allocated for chunks. 29.8KiB in use in bin. 1.7KiB client-requested in use in bin.
# 2023-11-09 17:22:31.202337: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-09 17:22:31.202357: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 5, Chunks in use: 3. 6.8KiB allocated for chunks. 3.5KiB in use in bin. 3.1KiB client-requested in use in bin.
# 2023-11-09 17:22:31.202381: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 338, Chunks in use: 337. 1015.2KiB allocated for chunks. 1012.8KiB in use in bin. 1010.9KiB client-requested in use in bin.
# 2023-11-09 17:22:31.202403: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 54, Chunks in use: 54. 224.8KiB allocated for chunks. 224.8KiB in use in bin. 221.0KiB client-requested in use in bin.
# 2023-11-09 17:22:31.202435: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 36, Chunks in use: 36. 441.0KiB allocated for chunks. 441.0KiB in use in bin. 435.0KiB client-requested in use in bin.
# 2023-11-09 17:22:31.202456: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 45, Chunks in use: 45. 1.37MiB allocated for chunks. 1.37MiB in use in bin. 1.35MiB client-requested in use in bin.
# 2023-11-09 17:22:31.202478: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 8, Chunks in use: 8. 333.5KiB allocated for chunks. 333.5KiB in use in bin. 258.0KiB client-requested in use in bin.
# 2023-11-09 17:22:31.202499: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 5, Chunks in use: 5. 480.0KiB allocated for chunks. 480.0KiB in use in bin. 480.0KiB client-requested in use in bin.
# 2023-11-09 17:22:31.202521: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 141.5KiB allocated for chunks. 141.5KiB in use in bin. 96.0KiB client-requested in use in bin.
# 2023-11-09 17:22:31.202539: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-09 17:22:31.202557: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-09 17:22:31.202579: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 37, Chunks in use: 37. 55.67MiB allocated for chunks. 55.67MiB in use in bin. 55.50MiB client-requested in use in bin.
# 2023-11-09 17:22:31.202603: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 284, Chunks in use: 284. 744.13MiB allocated for chunks. 744.13MiB in use in bin. 740.25MiB client-requested in use in bin.
# 2023-11-09 17:22:31.202642: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 12, Chunks in use: 12. 61.66MiB allocated for chunks. 61.66MiB in use in bin. 34.50MiB client-requested in use in bin.
# 2023-11-09 17:22:31.202663: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 109, Chunks in use: 109. 1.08GiB allocated for chunks. 1.08GiB in use in bin. 1.07GiB client-requested in use in bin.
# 2023-11-09 17:22:31.202683: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 156, Chunks in use: 155. 3.57GiB allocated for chunks. 3.55GiB in use in bin. 3.42GiB client-requested in use in bin.
# 2023-11-09 17:22:31.202706: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 3, Chunks in use: 3. 131.45MiB allocated for chunks. 131.45MiB in use in bin. 70.31MiB client-requested in use in bin.
# 2023-11-09 17:22:31.202730: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 82, Chunks in use: 82. 7.46GiB allocated for chunks. 7.46GiB in use in bin. 7.42GiB client-requested in use in bin.
# 2023-11-09 17:22:31.202753: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 5, Chunks in use: 5. 809.28MiB allocated for chunks. 809.28MiB in use in bin. 448.95MiB client-requested in use in bin.
# 2023-11-09 17:22:31.202772: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-11-09 17:22:31.202792: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 23.44MiB was 16.00MiB, Chunk State:
# 2023-11-09 17:22:31.202827: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 23.07MiB | Requested Size: 3.0KiB | in_use: 0 | bin_num: 16, prev:   Size: 31.2KiB | Requested Size: 31.2KiB | in_use: 1 | bin_num: -1, next:   Size: 23.44MiB | Requested Size: 23.44MiB | in_use: 1 | bin_num: -1
# 2023-11-09 17:22:31.202843: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 14901444608
# 2023-11-09 17:22:31.202862: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000000 of size 256 next 1
# 2023-11-09 17:22:31.202878: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000100 of size 1280 next 2
# 2023-11-09 17:22:31.202892: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000600 of size 256 next 3
# 2023-11-09 17:22:31.202907: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000700 of size 256 next 4
# 2023-11-09 17:22:31.202922: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000800 of size 256 next 5
# 2023-11-09 17:22:31.202937: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000900 of size 256 next 13
# 2023-11-09 17:22:31.202951: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000a00 of size 256 next 15
# 2023-11-09 17:22:31.202966: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000b00 of size 256 next 19
# 2023-11-09 17:22:31.202982: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2000c00 of size 3072 next 20
# 2023-11-09 17:22:31.202996: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2001800 of size 256 next 21
# 2023-11-09 17:22:31.203011: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2001900 of size 3072 next 22
# 2023-11-09 17:22:31.203025: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2002500 of size 256 next 14
# 2023-11-09 17:22:31.203041: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2002600 of size 256 next 24
# 2023-11-09 17:22:31.203055: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2002700 of size 256 next 25
# 2023-11-09 17:22:31.203070: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2002800 of size 256 next 16
# 2023-11-09 17:22:31.203086: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2002900 of size 3840 next 8
# 2023-11-09 17:22:31.203101: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb2003800 of size 3072 next 223
# 2023-11-09 17:22:31.203115: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 148fb
I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 21430272 totalling 61.31MiB
# 2023-11-09 17:23:51.256787: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 149 Chunks of size 24576000 totalling 3.41GiB
# 2023-11-09 17:23:51.256795: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 27145728 totalling 25.89MiB
# 2023-11-09 17:23:51.256803: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 32366080 totalling 30.87MiB
# 2023-11-09 17:23:51.256811: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 41280000 totalling 39.37MiB
# 2023-11-09 17:23:51.256819: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 45792000 totalling 43.67MiB
# 2023-11-09 17:23:51.256827: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 89075712 totalling 169.90MiB
# 2023-11-09 17:23:51.256835: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 34 Chunks of size 96000000 totalling 3.04GiB
# 2023-11-09 17:23:51.256842: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 43 Chunks of size 98304000 totalling 3.94GiB
# 2023-11-09 17:23:51.256851: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 133763840 totalling 127.57MiB
# 2023-11-09 17:23:51.256859: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 151070208 totalling 144.07MiB
# 2023-11-09 17:23:51.256867: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 154325760 totalling 147.18MiB
# 2023-11-09 17:23:51.256875: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 157625600 totalling 150.32MiB
# 2023-11-09 17:23:51.256883: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 172032000 totalling 164.06MiB
# 2023-11-09 17:23:51.256891: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 13.88GiB
# 2023-11-09 17:23:51.256899: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 14901444608 memory_limit_: 14901444608 available bytes: 0 curr_region_allocation_bytes_: 29802889216
# 2023-11-09 17:23:51.256913: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                     14901444608
# InUse:                     14900763904
# MaxInUse:                  14900874752
# NumAllocs:                     1544781
# MaxAllocSize:                196297728
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-11-09 17:23:51.257011: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ****************************************************************************************************
# 2023-11-09 17:23:51.257060: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at transpose_op.cc:183 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,12,250,64] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.005 MB of 0.005 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
#  View run <strong style="color:#cdcd00">chocolate-sweep-3</strong> at: <a href='https://wandb.ai/dlhs_rau/uminn/runs/cclm8rte' target="_blank">https://wandb.ai/dlhs_rau/uminn/runs/cclm8rte</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231109_172253-cclm8rte/logs</code>
# Run cclm8rte errored: ResourceExhaustedError()
# wandb: ERROR Run cclm8rte errored: ResourceExhaustedError()
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.

# %% [markdown]
# ### Evaluation

# %%
two_input_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_832254/3582198778.py in <module>
# ----> 1 two_input_model.summary()
#
# NameError: name 'two_input_model' is not defined

# %%
mse_test = two_input_model.evaluate(x=(dataset['predication']['test'], dataset['sentence']['test']), y=dataset['label']['test'])

# %%
y_pred = two_input_model.predict((dataset['predication']['test'], dataset['sentence']['test']))

# %%
strata = pd.DataFrame({'y_pred': y_pred.round().flatten(), 'label': dataset['label']['test'],
                       # 'predicate': sentences.predicate[0:test_size]
                      })

# %%
print("OVERALL")
print(classification_report(strata.label, strata.y_pred))
disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(strata.label, strata.y_pred, normalize='true')).plot()
plt.show()

# %%
# for stratum in strata.predicate.unique():
#     print(stratum)
#     df = strata[strata.predicate == stratum]
#     print(classification_report(df.label, df.y_pred))
#     print(strata[strata.predicate == stratum].y_pred.value_counts())
#     disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(df.label, df.y_pred, normalize='true')).plot()
#     plt.show()

# %%
wandb.finish()

# %%
concat_model.save('models/concat_resilient_music.keras')
